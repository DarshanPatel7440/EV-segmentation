# %% [markdown]
# # Imports Library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# # Import Dataset

# %%
data = pd.read_excel('Ev Sales.xlsx')
data.head()
# Out:
#         YEAR  2 W   3 W  4 W  BUS  TOTAL
# 0 2017-04-01   96  4748  198    0   5042
# 1 2017-05-01   91  6720  215    2   7028
# 2 2017-06-01  137  7178  149    1   7465
# 3 2017-07-01  116  8775  120    0   9011
# 4 2017-08-01   99  8905  137    0   9141

# %%
data['YEAR'] = pd.to_datetime(data['YEAR']).dt.date
data.head(6)
# Out:
#          YEAR  2 W   3 W  4 W  BUS  TOTAL
# 0  2017-04-01   96  4748  198    0   5042
# 1  2017-05-01   91  6720  215    2   7028
# 2  2017-06-01  137  7178  149    1   7465
# 3  2017-07-01  116  8775  120    0   9011
# 4  2017-08-01   99  8905  137    0   9141
# 5  2017-09-01  109  7414  193    0   7716

# %%
data.size
# Out:
# 444

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74 entries, 0 to 73
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   YEAR    74 non-null     object
#  1   2 W     74 non-null     int64
#  2   3 W     74 non-null     int64
#  3   4 W     74 non-null     int64
#  4   BUS     74 non-null     int64
#  5   TOTAL   74 non-null     int64
# dtypes: int64(5), object(1)
# memory usage: 3.6+ KB

# %%
data.describe()
# Out:
#                  2 W           3 W          4 W         BUS          TOTAL
# count      74.000000     74.000000    74.000000   74.000000      74.000000
# mean    16938.729730  14851.351351  1272.567568   82.310811   33144.959459
# std     25846.636971  11002.517635  1841.195763   79.696672   38251.453387
# min        85.000000    668.000000     3.000000    0.000000     958.000000
# 25%      1304.250000   7782.250000   187.750000   11.250000    9147.000000
# 50%      3014.500000  10619.500000   317.500000   74.500000   14526.000000
# 75%     23599.000000  18641.750000  1545.000000  113.500000   43902.750000
# max    105154.000000  45225.000000  8852.000000  331.000000  157788.000000

# %% [markdown]
# # Check the Null Values & Duplicates

# %%
data.isnull().sum()
# Out:
# YEAR     0
# 2 W      0
# 3 W      0
# 4 W      0
# BUS      0
# TOTAL    0
# dtype: int64

# %%
data.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 69    False
# 70    False
# 71    False
# 72    False
# 73    False
# Length: 74, dtype: bool

# %% [markdown]
# # Plots and Charts

# %%
plt.figure(figsize=(10, 8))
sns.lineplot(x=data['YEAR'], y=data['2 W'], marker='o', color='b')
plt.xlabel('Year', fontsize=14)
plt.ylabel('Sales of Electric 2-Wheelers', fontsize=14)
plt.xticks(rotation=45)
plt.title('Yearly Trend of Electric 2-Wheeler Sales')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12, 8))
plt.bar(data['YEAR'], data['2 W'], label='2-Wheelers', color='skyblue')
plt.bar(data['YEAR'], data['3 W'], bottom=data['2 W'], label='3-Wheelers', color='lightgreen')
plt.bar(data['YEAR'], data['4 W'], bottom=data['2 W'] + data['3 W'], label='4-Wheelers', color='orange')
plt.bar(data['YEAR'], data['BUS'], bottom=data['2 W'] + data['3 W'] + data['4 W'], label='Buses', color='red')
plt.xlabel('YEAR', fontsize=14)
plt.ylabel('Number of Vehicles Sold', fontsize=14)
plt.title('Year-wise Distribution of EV Sales by Vehicle Type', fontsize=16)
plt.xticks(rotation=45)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(14, 8))
bar_width = 0.2
x = np.arange(len(data['YEAR']))

plt.bar(x - bar_width*1.5, data['2 W'], width=bar_width, label='2-Wheelers', color='skyblue')
plt.bar(x - bar_width/2, data['3 W'], width=bar_width, label='3-Wheelers', color='lightgreen')
plt.bar(x + bar_width/2, data['4 W'], width=bar_width, label='4-Wheelers', color='orange')
plt.bar(x + bar_width*1.5, data['BUS'], width=bar_width, label='Buses', color='red')

plt.xlabel('Year', fontsize=14)
plt.ylabel('Number of Vehicles Sold', fontsize=14)
plt.title('Comparison of EV Sales by Vehicle Type Over Years', fontsize=16)
plt.xticks(x, data['YEAR'], rotation=45)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(data[['2 W', '3 W', '4 W', 'BUS']].corr(), annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Between Sales of Different EV Types', fontsize=16)
plt.show()

# %%
sns.pairplot(data)
# Out:
# C:\Users\Darshan Patel\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# # Import the second Data

# %%
data2 = pd.read_csv('ev_bharat_sales.csv')
data2.head()
# Out:
#    Sr. No.                State Name Total Electric Vehicle  \
# 0        1  Andaman & Nicobar Island                    162
# 1        2             Andra Pradesh                    NaN
# 2        3         Arunachal Pradesh                     20
# 3        4                     Assam                  64766
# 4        5                     Bihar                  83335
#
#   Total Non-Electric Vehicle        Total
# 0                   1,46,945     1,47,107
# 1                        NaN          NaN
# 2                   2,52,965     2,52,985
# 3                  46,77,053    47,41,819
# 4                1,04,07,078  1,04,90,413

# %%
data2['State Name'].unique()
# Out:
# array(['Andaman & Nicobar Island', 'Arunachal Pradesh', 'Assam', 'Bihar',
#        'Chandigarh', 'Chhattisgarh', 'Delhi', 'Goa', 'Gujarat', 'Haryana',
#        'Himachal Pradesh', 'Jammu and Kashmir', 'Jharkhand', 'Karnataka',
#        'Kerala', 'Ladakh', 'Maharashtra', 'Manipur', 'Meghalaya',
#        'Mizoram', 'Nagaland', 'Odisha', 'Puducherry', 'Punjab',
#        'Rajasthan', 'Sikkim', 'Tamil Nadu', 'Tripura', 'UT of DNH and DD',
#        'Uttarakhand', 'Uttar Pradesh', 'West Bengal'], dtype=object)

# %%
print(data2.shape)
print(data2.size)
# Out:
# (36, 5)
# 180

# %%
print(data2.info())
print(data2.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 5 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Sr. No.                     36 non-null     int64
#  1   State Name                  36 non-null     object
#  2   Total Electric Vehicle      32 non-null     object
#  3   Total Non-Electric Vehicle  32 non-null     object
#  4   Total                       32 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 1.5+ KB
# None
#          Sr. No.
# count  36.000000
# mean   18.500000
# std    10.535654
# min     1.000000
# 25%     9.750000
# 50%    18.500000
# 75%    27.250000
# max    36.000000

# %% [markdown]
# # check the NaN values

# %%
data2.isnull().sum()
# Out:
# Sr. No.                       0
# State Name                    0
# Total Electric Vehicle        4
# Total Non-Electric Vehicle    4
# Total                         4
# dtype: int64

# %%
data2.dropna(inplace=True)

# %%
data2['Total Electric Vehicle'] = data2['Total Electric Vehicle'].str.replace(',','').astype(int)
data2['Total Non-Electric Vehicle'] = data2['Total Non-Electric Vehicle'].str.replace(',','').astype(int)
data2['Total'] = data2['Total'].str.replace(',','').astype(int)

# %%
data2.describe()
# Out:
#          Sr. No.  Total Electric Vehicle  Total Non-Electric Vehicle  \
# count  32.000000               32.000000                3.200000e+01
# mean   18.625000            41699.531250                8.692801e+06
# std    10.557828            68261.115171                1.079020e+07
# min     1.000000               20.000000                3.830200e+04
# 25%     9.750000              485.250000                4.892432e+05
# 50%    18.500000            15807.500000                3.994547e+06
# 75%    27.250000            52766.750000                1.288081e+07
# max    36.000000           337180.000000                4.009249e+07
#
#               Total
# count  3.200000e+01
# mean   8.734500e+06
# std    1.084501e+07
# min    3.832800e+04
# 25%    4.896950e+05
# 50%    4.042434e+06
# 75%    1.290410e+07
# max    4.042967e+07

# %%
cmap = plt.get_cmap('Wistia', len(data2))
colors = [cmap(i) for i in range(len(data2))]
plt.pie(x= 'Total Electric Vehicle',
        labels= 'State Name',
        autopct='%2.2f%%',
        data = data2.sort_values('Total Electric Vehicle'),
        wedgeprops = {'width':0.6}, startangle=90,
        colors=colors)
plt.title('State wise Electric Vehicle Pie Chart')
plt.show()

# %%
df_sorted = data2.sort_values(by='Total Non-Electric Vehicle', ascending=False)

plt.bar(df_sorted['State Name'],df_sorted['Total Non-Electric Vehicle'],color = 'navy')
plt.xlabel('State Name')
plt.ylabel('Total Number of Vehicle')
plt.xticks(rotation = 90)
plt.show()

# %%
cmap = plt.get_cmap('twilight_shifted', len(data2))
colors = [cmap(i) for i in range(len(data2))]
plt.pie(x= 'Total',
        labels= 'State Name',
        autopct='%2.2f%%',
        data = data2.sort_values('Total'),
        wedgeprops = {'width':0.6}, startangle=90,
        colors=colors)
plt.title('State wise Total Pie Chart')
plt.show()

# %%
sns.pairplot(data2)
# Out:
# C:\Users\Darshan Patel\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# # Model Building

# %%
df2 = data2.copy()

# %%
col = ['Sr. No.','State Name']
df2.drop(col, axis=1, inplace=True)

# %%
df2.head()
# Out:
#    Total Electric Vehicle  Total Non-Electric Vehicle     Total  State_Encoded
# 0                     162                      146945    147107              0
# 2                      20                      252965    252985              1
# 3                   64766                     4677053   4741819              2
# 4                   83335                    10407078  10490413              3
# 5                    2812                      746881    749693              4

# %%
from sklearn.cluster import KMeans
k_values = range(2, 11)
inertia_values = []
for k in k_values:
    kmeans = KMeans(n_clusters=k, n_init=10, random_state=1234)
    kmeans.fit(df2)
    inertia_values.append(kmeans.inertia_)
plt.bar(k_values, inertia_values, color='#063e6b', alpha=0.7)
plt.title('Elbow Method for Optimal k')
plt.xlabel('Number of Segments (k)')
plt.ylabel('Sum of within cluster distances')
plt.show()

# %%
wcss = []

for i in range(1, 11):
    kmean = KMeans(n_clusters=i, init='k-means++', random_state=90)
    kmean.fit(df2)
    wcss.append(kmean.inertia_)

plt.figure(figsize=(8,6))
plt.title('Plot of the Elbow Method', size=15, family='serif')
plt.plot(range(1, 11), wcss)
plt.xticks(range(1, 11), family='serif')
plt.yticks(family='serif')
plt.xlabel('Number of Custers (K)', family='serif')
plt.ylabel('WCSS', family='serif')
plt.grid()
plt.tick_params(axis='both', direction='inout', length=6, color='purple', grid_color='lightgray', grid_linestyle='--')
plt.show()
# Out:
# C:\Users\Darshan Patel\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\Darshan Patel\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\Darshan Patel\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# ...

# %%
from sklearn.metrics import adjusted_rand_score
from sklearn.cluster import KMeans
import numpy as np
import matplotlib.pyplot as plt

results = {}
for k in range(2, 5):
    model = KMeans(n_clusters=k, n_init='auto', random_state=1234).fit(df2)
    results[str(k)] = model.labels_
    df['Cluster Number'] = model.labels_

ari_values = np.array([[adjusted_rand_score(results[str(k1)], results[str(k2)]) for k2 in range(2, 5)] for k1 in range(2, 5)])

plt.boxplot(ari_values.T, labels=list(range(2, 5)))
plt.xlabel('Number of Segments (k)')
plt.ylabel('Adjusted Rand Index')
plt.title('Global stability of k-means segmentation solutions')
plt.show()

# %%
from sklearn.metrics import silhouette_score

silhouette_scores = []
for k in range(2, 5):
    model = KMeans(n_clusters=k, n_init='auto', random_state=1234).fit(df2)
    score = silhouette_score(df2, model.labels_)
    silhouette_scores.append(score)

plt.plot(range(2, 5), silhouette_scores, marker='o')
plt.xlabel('Number of Segments (k)')
plt.ylabel('Silhouette Score')
plt.title('Silhouette Analysis for Optimal k')
plt.show()

# %%
kmean = KMeans(n_clusters=4, init='k-means++', random_state=90)
kmean.fit(df2)
# Out:
# C:\Users\Darshan Patel\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# KMeans(n_clusters=4, random_state=90)

# %%
y_kmeans = kmean.predict(df2)

plt.scatter(df2.iloc[:, 0], df2.iloc[:, 1], c=y_kmeans, s=50, cmap='viridis')
plt.scatter(kmean.cluster_centers_[:, 0], kmean.cluster_centers_[:, 1], c='red', s=200, alpha=0.75, marker='*')

plt.title("K-Means Clustering")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.show()
